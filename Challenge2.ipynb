# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Easy: Get the computer to choose a number between 1â3 at random. 
'''
import random
value = random.randint(20,30)
print("Starting number:",value)

def system(value):
    value = int(value)
    player = None
    while value > 0:
        choice = int(input("How many do you want to remove?"))
        value = value - choice
        print(value,"left")
        player = "Computer"
        if value > 0:
            com_choice = random.randint(1,3)
            print("Computer removes",com_choice)
            value = value - com_choice
            print(value,"left")
            player = "You"
    print(player,"win")

system(value)
# Out:
# Starting number: 29
# How many do you want to remove?27
# 2 left
# Computer removes 1
# 1 left
# How many do you want to remove?1
# 0 left
# Computer win

# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Hard: Get the computer to employ a strategy to try and win. 
'''

import random
value = random.randint(20,30)
print("Starting number:",value)

def system(value):
    value = int(value)
    player = None
    while value > 0:
        choice = int(input("How many do you want to remove?"))
        value = value - choice
        print(value,"left")
        player = "Computer"
        if value > 0:
            com_choice = (value - 1) % 4
            if com_choice > 0:
                print("Computer removes",com_choice)
                value = value - com_choice
                print(value,"left")
            else:
                com_choice = random.randint(1,3)
                print("Computer removes",com_choice)
                value = value - com_choice
                print(value,"left")
            player = "You"
    print(player,"win")

system(value)
# Out:
# Starting number: 23
# How many do you want to remove?3
# 20 left
# Computer removes 3
# 17 left
# How many do you want to remove?3
# 14 left
# Computer removes 1
# 13 left
# How many do you want to remove?3
# 10 left
# Computer removes 1
# 9 left
# How many do you want to remove?3
# 6 left
# Computer removes 1
# 5 left
# How many do you want to remove?3
# 2 left
# Computer removes 1
# 1 left
# How many do you want to remove?1
# 0 left
# Computer win

# %%
''' 
Write a program for a Higher / Lower guessing game.
The computer randomly generates a sequence of up to 10 numbers
between 1 and 13. The player after seeing each number in turn
has to decide whether the next number is higher or lower.
If you get 10 guesses right you win the game.

Starting number : 12
Higher(H) or lower(L)? L
Next number 8
Higher(H) or lower(L)? L
Next number 11
You lose

Hints
- Use a condition controlled loop (do until, while etc) to control the
game.
- You do not need to remember all 10 numbers, but  just the current and
the next number.
- Remember to keep a count of the number of guesses. 
''' 
import random
curr = random.randint(1,13)
print("Starting number:" ,curr)
count = 0
while count < 10:
    choice = input("Higher(H) or Lower(L)?")
    value = random.randint(1,13)
    if choice == "L" and value < curr:
        count = count + 1
        curr = value
    elif choice == "H" and value > curr:
        count = count + 1
        curr = value
    else:
        print("You lose")
        break
# Out:
# Starting number: 4
# Higher(H) or Lower(L)?H
# You lose

# %%
'''
Extend the above Higher / Lower number guessing game by
- Giving the player two lives
- Allowing only H or L to be entered 
'''
import random
curr = random.randint(1,13)
print("Starting number:" ,curr)
count = 0
lives = 2
while count < 10 and lives > 0:
    choice = input("Higher(H) or Lower(L)?")
    value = random.randint(1,13)
    if choice == "L" and value < curr:
        count = count + 1
        curr = value
    elif choice == "H" and value > curr:
        count = count + 1
        curr = value
    else:
        lives = lives - 1
        print("1 live lost")
if lives == 0:
    print("You Lose")
else:
    print("You Win")
# Out:
# Starting number: 4
# Higher(H) or Lower(L)?H
# Higher(H) or Lower(L)?H
# 1 live lost
# Higher(H) or Lower(L)?H
# 1 live lost
# You Lose

# %%
'''
Write a program to count the number of words in a sentence.
The user enters a sentence.
The program outputs the number of words in the sentence.
Hint: Look for spaces and full stops in the string. 
'''
sentence = input("Write a sentence: ")
words = 0
for char in sentence:
    if char == " ":
        words = words + 1
    elif char == ".":
        words = words + 1
    else:
        pass
print("There are",words,"words")
# Out:
# Write a sentence: Magick Mike XXL is the best.
# There are 6 words

# %%
'''
Write a program that will display a sentence backwards after being entered.
Note: You may not use the Python list reverse() function. ;)
'''
sentence = input("Write a sentence: ")
value = -len(sentence)
array = []
for char in sentence:
    array.append(char)
for i in range(-1,value - 1,-1):
    print(array[i],end = '')
# Out:
# Write a sentence: magick
# kcigam
